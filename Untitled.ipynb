# %%
import numpy as np
import pandas as pd

# %%
import xlrd as ex

# %%
df = pd.read_excel('strikemap.xlsx')

# %%
df
# Out:
#                                                    Title        Date  \
# 0      Workers protest against wage arrears in Xian, ...  2021-08-30
# 1      Workers protest against wage arrears of a cons...  2021-08-29
# 2      Taxi drivers protest against shared electric b...  2021-08-28
# 3      Workers protest against wage arrears of a cons...  2021-08-28
# 4      Workers protests against wage arrears of a con...  2021-08-27
# ...                                                  ...         ...
# 11197  Workers at an electronic factory in Dongguan, ...  2015-01-04
# 11198  Hundred of coal mine workers in Tengzhou, Shan...  2015-01-04
# 11199  Workers at a bankrupted bar in Wuxi, Jiangsu, ...  2015-01-01
# 11200  Construction workers at a developer in Yanchen...  2015-01-01
# 11201  Workers at a bankrupted coal mine in Yibin, Si...  2015-01-01
#
#                                              Description   Province  \
# 0      Workers protest against wage arrears in Xian, ...        陕西省
# ...

# %%
shanghaiStrikes = df[(df["City"] == ("Shanghai"))]

# %%
shanghaiStrikes
# Out:
#                                                    Title        Date  \
# 16     Employees protest against wage arrears of a st...  2021-08-17
# 25     Workers protest against wage arrears of Zhangm...  2021-08-12
# 71     Delivery workers protest against wage arrears ...  2021-07-25
# 90     Workers protest against wage arrears of a mach...  2021-07-20
# 145    Delivery workers of Yunda go on strike in Shan...  2021-07-06
# ...                                                  ...         ...
# 11021  Construction workers at a business building in...  2015-01-26
# 11045  Workers at a KTV in Shanghai demand wage in ar...  2015-01-22
# 11150  Workers at a bankrupted spa in Shanghai take t...  2015-01-12
# 11172  Construction workers at a developer in Shangha...  2015-01-07
# 11190  300 electronic factory workers in Shanghai str...  2015-01-05
#
#                                              Description  Province      City  \
# ...

# %%
shanghaiStrikes["Title"]
# Out:
# 16       Employees protest against wage arrears of a st...
# 25       Workers protest against wage arrears of Zhangm...
# 71       Delivery workers protest against wage arrears ...
# 90       Workers protest against wage arrears of a mach...
# 145      Delivery workers of Yunda go on strike in Shan...
#                                ...
# 11021    Construction workers at a business building in...
# 11045    Workers at a KTV in Shanghai demand wage in ar...
# 11150    Workers at a bankrupted spa in Shanghai take t...
# 11172    Construction workers at a developer in Shangha...
# 11190    300 electronic factory workers in Shanghai str...
# Name: Title, Length: 243, dtype: object

# %%
y2021 = shanghaiStrikes[shanghaiStrikes['Date'].str.contains('2021')]
y2020 = shanghaiStrikes[shanghaiStrikes['Date'].str.contains('2020')]
y2019 = shanghaiStrikes[shanghaiStrikes['Date'].str.contains('2019')]
y2018 = shanghaiStrikes[shanghaiStrikes['Date'].str.contains('2018')]
y2017 = shanghaiStrikes[shanghaiStrikes['Date'].str.contains('2017')]
y2016 = shanghaiStrikes[shanghaiStrikes['Date'].str.contains('2016')]
y2015 = shanghaiStrikes[shanghaiStrikes['Date'].str.contains('2015')]

# %%
len(y2021.index)
# Out:
# 14

# %%
shanghaiStrikes.to_excel("shanghaiStrikes.xlsx")
